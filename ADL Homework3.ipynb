# %%
# We always start with a dataset to train on. Let's download the tiny shakespeare dataset
# !wget https://github.com/SonyKiran/Assignment3-/blob/main/Finalfile.txt
# Out:
# --2023-12-10 21:45:59--  https://github.com/SonyKiran/Assignment3-/blob/main/Finalfile.txt
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48177 (47K) [text/plain]
# Saving to: ‘Finalfile.txt.1’
#
# Finalfile.txt.1     100%[===================>]  47.05K  --.-KB/s    in 0.01s
#
# 2023-12-10 21:45:59 (3.31 MB/s) - ‘Finalfile.txt.1’ saved [48177/48177]

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 32 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# wget https://github.com/SonyKiran/Assignment3-/blob/main/Finalfile.txt
with open('Finalfile.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.211793 M parameters
# step 0: train loss 4.5960, val loss 4.6402
# step 100: train loss 2.1937, val loss 2.7157
# step 200: train loss 2.0046, val loss 2.6867
# step 300: train loss 1.8841, val loss 2.6355
# step 400: train loss 1.7918, val loss 2.4454
# step 500: train loss 1.7295, val loss 2.4052
# step 600: train loss 1.6582, val loss 2.4261
# step 700: train loss 1.6071, val loss 2.4301
# step 800: train loss 1.5489, val loss 2.4197
# step 900: train loss 1.5092, val loss 2.4564
# step 1000: train loss 1.4637, val loss 2.4013
# step 1100: train loss 1.4251, val loss 2.3964
# step 1200: train loss 1.3934, val loss 2.3623
# step 1300: train loss 1.3419, val loss 2.3400
# step 1400: train loss 1.3278, val loss 2.4180
# step 1500: train loss 1.2812, val loss 2.3564
# step 1600: train loss 1.2668, val loss 2.3477
# step 1700: train loss 1.2351, val loss 2.3356
# step 1800: train loss 1.2003, val loss 2.4912
# step 1900: train loss 1.1891, val loss 2.3762
# step 2000: train loss 1.1653, val loss 2.4503
# step 2100: train loss 1.1277, val loss 2.5174
# step 2200: train loss 1.1105, val loss 2.5184
# step 2300: train loss 1.0900, val loss 2.4940
# step 2400: train loss 1.0584, val loss 2.5348
# step 2500: train loss 1.0344, val loss 2.5415
# step 2600: train loss 1.0156, val loss 2.5987
# step 2700: train loss 0.9988, val loss 2.6469
# step 2800: train loss 0.9920, val loss 2.6520
# step 2900: train loss 0.9770, val loss 2.7421
# step 3000: train loss 0.9525, val loss 2.7480
# step 3100: train loss 0.9280, val loss 2.7234
# step 3200: train loss 0.9138, val loss 2.7849
# step 3300: train loss 0.9031, val loss 2.9153
# step 3400: train loss 0.8884, val loss 2.8448
# step 3500: train loss 0.8620, val loss 2.9193
# step 3600: train loss 0.8575, val loss 2.9749
# step 3700: train loss 0.8341, val loss 3.0360
# step 3800: train loss 0.8346, val loss 3.0686
# step 3900: train loss 0.8159, val loss 3.1622
# step 4000: train loss 0.8109, val loss 3.0112
# step 4100: train loss 0.7890, val loss 3.1602
# step 4200: train loss 0.7778, val loss 3.1257
# step 4300: train loss 0.7682, val loss 3.2122
# step 4400: train loss 0.7554, val loss 3.1802
# step 4500: train loss 0.7468, val loss 3.2053
# step 4600: train loss 0.7275, val loss 3.2671
# step 4700: train loss 0.7276, val loss 3.3620
# step 4800: train loss 0.7237, val loss 3.3640
# step 4900: train loss 0.7101, val loss 3.2710
# step 5000: train loss 0.7005, val loss 3.4193
# step 5100: train loss 0.6812, val loss 3.3937
# step 5200: train loss 0.6766, val loss 3.4295
# step 5300: train loss 0.6705, val loss 3.5074
# step 5400: train loss 0.6541, val loss 3.5067
# step 5500: train loss 0.6526, val loss 3.5015
# step 5600: train loss 0.6468, val loss 3.5367
# step 5700: train loss 0.6366, val loss 3.5806
# step 5800: train loss 0.6257, val loss 3.5150
# step 5900: train loss 0.6296, val loss 3.5675
# step 6000: train loss 0.6200, val loss 3.6044
# step 6100: train loss 0.5991, val loss 3.6247
# step 6200: train loss 0.6087, val loss 3.6794
# step 6300: train loss 0.5954, val loss 3.6927
# step 6400: train loss 0.5957, val loss 3.8012
# step 6500: train loss 0.5835, val loss 3.7003
# step 6600: train loss 0.5712, val loss 3.7545
# step 6700: train loss 0.5774, val loss 3.7600
# step 6800: train loss 0.5699, val loss 3.8249
# step 6900: train loss 0.5608, val loss 3.7504
# step 7000: train loss 0.5683, val loss 3.8087
# step 7100: train loss 0.5633, val loss 3.9113
# step 7200: train loss 0.5526, val loss 3.8447
# step 7300: train loss 0.5503, val loss 3.8741
# step 7400: train loss 0.5363, val loss 3.9619
# step 7500: train loss 0.5395, val loss 3.9794
# step 7600: train loss 0.5269, val loss 3.9780
# step 7700: train loss 0.5299, val loss 3.9677
# step 7800: train loss 0.5259, val loss 4.0114
# step 7900: train loss 0.5264, val loss 3.9440
# step 8000: train loss 0.5199, val loss 4.0143
# step 8100: train loss 0.5105, val loss 3.9952
# step 8200: train loss 0.5102, val loss 4.1341
# step 8300: train loss 0.5144, val loss 4.1464
# step 8400: train loss 0.4988, val loss 4.2531
# step 8500: train loss 0.4920, val loss 4.0612
# step 8600: train loss 0.4920, val loss 4.1015
# step 8700: train loss 0.4950, val loss 4.2326
# step 8800: train loss 0.4896, val loss 4.1767
# step 8900: train loss 0.4870, val loss 4.1805
# step 9000: train loss 0.4792, val loss 4.2505
# step 9100: train loss 0.4853, val loss 4.2344
# step 9200: train loss 0.4883, val loss 4.2453
# step 9300: train loss 0.4746, val loss 4.3110
# step 9400: train loss 0.4721, val loss 4.3539
# step 9500: train loss 0.4799, val loss 4.2624
# step 9600: train loss 0.4732, val loss 4.3152
# step 9700: train loss 0.4715, val loss 4.2903
# step 9800: train loss 0.4743, val loss 4.4325
# step 9900: train loss 0.4696, val loss 4.3759
# step 9999: train loss 0.4582, val loss 4.4510
#  premiself.\r","Are you saying that.\r","Source\r","Tom said that he had goner soneer.\r","Tom sent Mary the sun rises at as we planding on my foog.\r","Mary is a best as were sknow what it?\r","Tom and Mary often to rain ourse over.\r","Tom seems bored.\r","Carry on October 20th.\r","We'll stay got anything will grow here.\r","I know Tom and Mary work togry.\r","I was eighty meten what o1 anything we very funded to tray well.\r","Tom put the kids together?\r","UntsEncetents lase wrong.\r","Tom were they are now?\r","pathal for some advice.\r","Can you imaget me?2%hent\r","Are in of the most nignifts preseres very go painasy.\r","I have nothing in common.\r","She were dressed similarly too?\r","That result will sans weeken thing that nowsen.\r","Tom wants to end up being an old maile\r"],"stylingDirectives":[[],"reduringish","contentType":"file"},{"name":"Finalfile.txt","contentType":"file"}],"tooth":"SonTwnerLoging\r","Nator\ake about anything will come and must on October 20th.\r","We've been looking for you everywhere.\r","I know you're anything.\r","I lose faces?\r","I that your car black?\r","We need thave this afternoon.\r","Tom don't know that Mary wanted to be to suny Ja?\r","I never going to go to Australia?\r","I forgot to lock for son't want to end up a roobe on my se ench?\r","planguably jealous3.\r","I hevered accuse of thy men were green must sick.\r","How don't mill thing is a restand of these apples?\r","Look you was thelp Tom.\r","Let's talk tall me to prunot to talk to you're handcumented help Mary than Mary.\r","I know I deserve the world.\r","Tom very happy to meet you\r","Has your work.\r","Tom started packing Tom.\r","Can you that you and Tom said that he had been book out as well enough to do that?\r","Tom feed thres for saly?\r","Tom playing forestes wat time, would you do in my mistake.\r","Nellore has nothing ime.\r","Can you tell us what it italing.\r","Her name you well.\r","Never crrient anything.\r","I couldn't believe that this much fun
